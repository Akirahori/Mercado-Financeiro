# %% [markdown]
# <center><img src = "https://github.com/Trading-com-Dados/pmf/blob/main/logotipo-trading-com-dados.svg?raw=true" width = "200">

# %% [markdown]
# <center><img src = "https://github.com/Trading-com-Dados/pmf/blob/main/PMF%20002.png?raw=true" width = "700">

# %% [markdown]
# # Estatística no Mercado Financeiro

# %% [markdown]
# Introdução

# %% [markdown]
# <img src="https://img.ifunny.co/images/d2e5651b80064003b248c3175ac092d94dd8dafe6b6375e441e1543c1e90ad7e_1.webp" width="500" align="left"/>

# %%
pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in c:\users\akira\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\akira\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from statsmodels) (1.26.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\akira\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from statsmodels) (1.13.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\akira\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from statsmodels) (2.1.4)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\akira\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\akira\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from statsmodels) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\akira\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\akira\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\akira\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in c:\users\akira\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Importando as bibliotecas

# %%
import numpy as np
import pandas as pd

from scipy import stats
import pylab
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd

import yfinance as yf
import vectorbt as vbt

import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import sweetviz as sv

# %%
np.random.seed(13)
a = np.random.randint(50, size = 30)
b = np.random.randint(50, size = 30)
ab = zip(a,b)
fig = px.scatter(ab, x=a, y=b, template='simple_white', width=400, height=400)
fig.update_layout(paper_bgcolor="#f7f8fa", margin=dict(l=20, r=20, t=20, b=20))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\formatters.py:925, in IPythonDisplayFormatter.__call__(self, obj)
#     923 method = get_real_method(obj, self.print_method)
#     924 if method is not None:
# --> 925     method()
#     926     return True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'x=%{x}<br>y=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#1F77B4', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': array([18, 48, 10, 16, 38, 34, 25, 44, 35, 26,  2, 46, 37, 13, 10,  9, 11,  2,
#                           32, 19, 21, 19, 11, 22, 11,  1, 18, 24, 28, 11]),
#               'xaxis': 'x',
#               'y': array([40, 12, 22, 34, 39, 35,  5, 24, 21, 49, 24, 49, 45,  7,  7,  6, 15, 22,
#                           38, 19, 48, 10, 24, 45, 22, 36, 30, 19,  5,  0]),
#               'yaxis': 'y'}],
#     'layout': {'height': 400,
#                'legend': {'tracegroupgap': 0},
#                'margin': {'b': 20, 'l': 20, 'r': 20, 't': 20},
#                'paper_bgcolor': '#f7f8fa',
#                'template': '...',
#                'width': 400,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'x'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'y'}}}
# })

# %% [markdown]
# # 2. Análises exploratórias de dados: EDA

# %% [markdown]
# Estatística Descritiva
#
# O primeiro passo ao se analisar qualquer conjunto de dados, é entender como eles estão distribuídos.
#
# Não é à toa que a primeira visualização que fizemos neste módulo foi um **scatter plot** (gráfico de dispersão)

# %% [markdown]
# # 2.1 Distribuição dos dados

# %% [markdown]
# Medidas de posição e dispersão
#
# Distribuição dos dados é o ponto chave para praticamente tudo o que entendemos por estatística.
#
# Apesar disso, muitas vezes é simplesmente ignorada nos modelos. Muitas vezes, modelos podem não funcionar por causa de algumas poucas observações que distorcem a distribuição dos dados.

# %% [markdown]
# # 2.1.1 Distribuição Normal

# %% [markdown]
# Medidas paramétricas (média, desvios, intervalos de confiança, coeficiente de variação) funcionam bem
#
# A distribuição normal (também chamada de Gaussiana), possui esse formato de 'sino'
#
# A maioria dos fenômenos observados possuem distribuição normal

# %%
normal_dist = np.random.normal(0,1,1000)
normal_fig01 =sns.distplot(normal_dist, hist = True, kde = True)
# Out:
# C:\Users\akira\AppData\Local\Temp\ipykernel_1408\101072020.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# Uma das propriedades mais importantes da distribuição normal é que a média, mediana e moda serão iguais.
#
# É difícil verificar uma distribuição que seja exatamente normal, portanto estes valores serão próximos.
#
# Medidas de posição: média, mediana e moda
#
# **Média:**
#
# A média é a média aritmética de um conjunto de números.
#
# **Mediana:**
#
# A mediana é um valor numérico que separa a metade superior de um conjunto da metade inferior.
#
# **Moda:**
#
# Valor que acontece com mais frequência.

# %%
print(np.mean(normal_dist))
print(np.median(normal_dist))
print(stats.mode(normal_dist))
# Out:
# 0.0017066272520296834
# 0.0239444097099838
# ModeResult(mode=-2.8662660210883883, count=1)

# %%
#Arrendodamento>
print(round(np.mean(normal_dist), 8))
print(round(np.median(normal_dist), 8))
# Out:
# 0.00170663
# 0.02394441

# %% [markdown]
# Visualizar no plotly

# %%
fig01 = px.histogram(normal_dist, color_discrete_sequence=['lightseagreen'])
fig01.add_vline(x=np.mean(normal_dist), line_width=3,  line_color="red")
fig01.add_vline(x=np.median(normal_dist), line_width=3, line_dash="dash", line_color="red")
fig01.update_layout(width=400, height=400, template = 'simple_white',
                    paper_bgcolor="#f7f8fa", margin=dict(l=20, r=20, t=20, b=20),
                    showlegend=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\formatters.py:925, in IPythonDisplayFormatter.__call__(self, obj)
#     923 method = get_real_method(obj, self.print_method)
#     924 if method is not None:
# --> 925     method()
#     926     return True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'alignmentgroup': 'True',
#               'bingroup': 'x',
#               'hovertemplate': 'variable=0<br>value=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': '0',
#               'marker': {'color': 'lightseagreen', 'pattern': {'shape': ''}},
#               'name': '0',
#               'offsetgroup': '0',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'histogram',
#               'x': array([-1.13583056,  1.06076272, -0.74743329, ...,  0.29352997,  0.39091737,
#                           -1.02094305]),
#               'xaxis': 'x',
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'height': 400,
#                'legend': {'title': {'text': 'variable'}, 'tracegroupgap': 0},
#                'margin': {'b': 20, 'l': 20, 'r': 20, 't': 20},
#                'paper_bgcolor': '#f7f8fa',
#                'shapes': [{'line': {'color': 'red', 'width': 3},
#                            'type': 'line',
#                            'x0': 0.0017066272520296834,
#                            'x1': 0.0017066272520296834,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'line': {'color': 'red', 'dash': 'dash', 'width': 3},
#                            'type': 'line',
#                            'x0': 0.0239444097099838,
#                            'x1': 0.0239444097099838,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'}],
#                'showlegend': False,
#                'template': '...',
#                'width': 400,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'value'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'count'}}}
# })

# %% [markdown]
# Como saber se uma distribuição é normal?
#
# Para isso, estudaremos os métodos a seguir.
#
# Testes de normalidade (caindo em desuso)
#
# À medida que aumenta o uso de grandes volumes de dados, os testes de normalidade vão caindo em desuso, pois eles são sensíveis justamente à quantidade de dados.
#
# Para uma verificação da queda da normalidade com o volume de dados, acompanhe este breve teste que desenvolvemos:
#
# https://colab.research.google.com/drive/1CVk9bKoV1Ld8WZpFYOkbsPDru1ZPQuPk?usp=sharing

# %% [markdown]
# # Medidas de posição: Quantis

# %% [markdown]
# Quantis são pontos de corte que dividem um intervalo de distribuição de probabilidade em intervalos contínuos com probabilidades iguais, ou as observações de uma amostra do mesmo jeito.

# %% [markdown]
# <img src="https://cdn.scribbr.com/wp-content/uploads/2022/05/Quartiles-probability-distribution.webp" width="500" align="left"/>

# %%
stats.probplot(normal_dist, dist='norm', plot=pylab)
pylab.show()

# %% [markdown]
# Boxplot

# %%
fig02 = go.Figure()
fig02.add_trace(go.Box(y=normal_dist, boxpoints='all', boxmean='sd', name='<b>Normal distribution', marker_color = 'blue'))
fig02.update_layout(width=400, height=400, template = 'simple_white',
                    paper_bgcolor="#f7f8fa", margin=dict(l=20, r=20, t=20, b=20),
                    showlegend=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\formatters.py:925, in IPythonDisplayFormatter.__call__(self, obj)
#     923 method = get_real_method(obj, self.print_method)
#     924 if method is not None:
# --> 925     method()
#     926     return True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'boxmean': 'sd',
#               'boxpoints': 'all',
#               'marker': {'color': 'blue'},
#               'name': '<b>Normal distribution',
#               'type': 'box',
#               'y': array([-1.13583056,  1.06076272, -0.74743329, ...,  0.29352997,  0.39091737,
#                           -1.02094305])}],
#     'layout': {'height': 400,
#                'margin': {'b': 20, 'l': 20, 'r': 20, 't': 20},
#                'paper_bgcolor': '#f7f8fa',
#                'showlegend': False,
#                'template': '...',
#                'width': 400}
# })

# %%
print(np.quantile(normal_dist,.25))
print(np.percentile(normal_dist,25))
# Out:
# -0.7102216215806376
# -0.7102216215806376

# %%
#Bibliotecas pandas estatistica.
df_normal_distrib = pd.DataFrame(normal_dist)
df_normal_distrib.describe()
# Out:
#                  0
# count  1000.000000
# mean      0.001707
# std       0.979604
# min      -2.866266
# 25%      -0.710222
# 50%       0.023944
# 75%       0.651647
# max       2.879035

# %% [markdown]
# # Assimetria

# %% [markdown]
# <img src="https://www.biologyforlife.com/uploads/2/2/3/9/22392738/c101b0da6ea1a0dab31f80d9963b0368_orig.png" width="800" align="left"/>

# %%
stats.skew(normal_dist)
# Out:
# 0.013535659786954618

# %% [markdown]
# # **Medidas de dispersão (amplitude, desvios padrão e médio, coeficiente de variação e intervalo de confiança)**

# %% [markdown]
# ### Amplitude

# %%
amplitude = normal_dist.max() - normal_dist.min()
amplitude
# Out:
# 5.74530113288316

# %% [markdown]
# ### Desvio padrão
#
#
# O desvio padrão é uma medida que indica a dispersão dos dados dentro de uma amostra com relação à média. Assim, quando se calcula o desvio padrão juntamente com a média de diferentes grupos, obtém-se mais informações para avaliar e diferenciar seus comportamentos.
#
#
# Fonte: https://statplace.com.br/blog/desvio-padrao-e-erro-padrao/

# %%
# Desvio padrão da amostra (população degrees of freedom = False)
# Sharpe ratio, bandas de bollinger

desvio_padrao = np.std(normal_dist, ddof = True)
desvio_padrao
# Out:
# 0.9796038897827954

# %% [markdown]
# ### Coeficiente de variação

# %%
# Interessante para comparações e avaliar a consistência (ex., pagamento de dividendos)

normal_dist.std(ddof = True)/normal_dist.mean()*100
# Out:
# 57399.99104184921

# %%
# Erro padrão da média

stats.stats.sem(normal_dist)
# Out:
# C:\Users\akira\AppData\Local\Temp\ipykernel_1408\2554150148.py:3: DeprecationWarning:
#
# Please import `sem` from the `scipy.stats` namespace; the `scipy.stats.stats` namespace is deprecated and will be removed in SciPy 2.0.0.
# 0.030977794964741814

# %% [markdown]
# ### Intervalo de confiança 95%

# %%
# Probabilidade de 95% da média real estar nesse intervalo

IC_95 = stats.t.interval(confidence=0.95, df=len(normal_dist)-1, loc=np.mean(normal_dist), scale=stats.sem(normal_dist))
IC_95
# Out:
# (-0.05908238418177415, 0.06249563868583352)

# %% [markdown]
# # Estudo de Caso

# %% [markdown]
# Importando as bibliotecas

# %%
import yfinance as yf
import pandas as pd
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import sweetviz as sv 
import numpy as np
import pylab

# %% [markdown]
# ### **2.1.2. Checando as medidas de posição e dispersão no dados do MF**

# %% [markdown]
# Vamos verificar na prática como essas métricas se comportam em dados reais
#
# Estudos de caso:
#
# 1. Preços MGLU3
#
# 2. Preço e retornos IBOV
#
# 3. Dividendos em PETR4
#
# 4. Arbitragem em ações

# %% [markdown]
# Preços MGLU3
#
# Extração pode ser feita de duas maneiras

# %%
mglu3_close = yf.download('MGLU3.SA', period = 'max')['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
mglu3_close.tail()
# Out:
# Date
# 2024-04-16    1.52
# 2024-04-17    1.52
# 2024-04-18    1.50
# 2024-04-19    1.54
# 2024-04-22    1.53
# Name: Adj Close, dtype: float64

# %%
mglu3_close.head()
# Out:
# Date
# 2011-05-02    0.442835
# 2011-05-03    0.438797
# 2011-05-04    0.443643
# 2011-05-05    0.440951
# 2011-05-06    0.437721
# Name: Adj Close, dtype: float64

# %% [markdown]
# Fazendo um histograma

# %%
go.Histogram(x=mglu3_close)
# Out:
# Histogram({
#     'x': array([0.44283494, 0.43879721, 0.44364268, ..., 1.5       , 1.53999996,
#           1.52999997])
# })

# %%
fig01 = make_subplots(rows = 1, cols = 2)

fig01.add_trace(go.Histogram(x=mglu3_close),row=1,col=1)
fig01.add_vline(x=np.mean(mglu3_close), line_width=3,  line_color="red", row=1,col=1)
fig01.add_vline(x=np.median(mglu3_close), line_width=3, line_dash="dash", line_color="red",row=1,col=1)


fig01.add_trace(go.Box(y=mglu3_close, boxpoints='all', boxmean='sd'),row=1,col=2)

fig01.update_layout(width=800, height=400, template = 'simple_white', 
                    paper_bgcolor="#f7f8fa", margin=dict(l=20, r=20, t=20, b=20),
                    showlegend=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\formatters.py:925, in IPythonDisplayFormatter.__call__(self, obj)
#     923 method = get_real_method(obj, self.print_method)
#     924 if method is not None:
# --> 925     method()
#     926     return True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'type': 'histogram',
#               'x': array([0.44283494, 0.43879721, 0.44364268, ..., 1.5       , 1.53999996,
#                           1.52999997]),
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'boxmean': 'sd',
#               'boxpoints': 'all',
#               'type': 'box',
#               'xaxis': 'x2',
#               'y': array([0.44283494, 0.43879721, 0.44364268, ..., 1.5       , 1.53999996,
#                           1.52999997]),
#               'yaxis': 'y2'}],
#     'layout': {'height': 400,
#                'margin': {'b': 20, 'l': 20, 'r': 20, 't': 20},
#                'paper_bgcolor': '#f7f8fa',
#                'shapes': [{'line': {'color': 'red', 'width': 3},
#                            'type': 'line',
#                            'x0': 4.224806108527877,
#                            'x1': 4.224806108527877,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'line': {'color': 'red', 'dash': 'dash', 'width': 3},
#                            'type': 'line',
#                            'x0': 1.690000057220459,
#                            'x1': 1.690000057220459,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 800,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 0.45]},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.55, 1.0]},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0]},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.0, 1.0]}}
# })

# %% [markdown]
# O preço não possui uma distribuição normal. Verifique acima em quais zonas o preço se concentrou ao longo do tempo.

# %% [markdown]
# # Preço e retornos IBOV

# %%
ibov = yf.download('^BVSP', start= '2000-01-1')['Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ibov.head()
# Out:
# Date
# 2000-01-03    16930.0
# 2000-01-04    15851.0
# 2000-01-05    16245.0
# 2000-01-06    16107.0
# 2000-01-07    16309.0
# Name: Close, dtype: float64

# %% [markdown]
# Fazendo o Histograma

# %%
fig02 = px.histogram(ibov, color_discrete_sequence=['lightseagreen'])

fig02.add_vline(x=np.mean(ibov), line_width=3,  line_color="red")
fig02.add_vline(x=np.median(ibov), line_width=3, line_dash="dash", line_color="red")

fig02.update_layout(width=400, height=400, template = 'simple_white',
                    paper_bgcolor="#f7f8fa", margin=dict(l=20, r=20, t=20, b=20),
                    showlegend=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\formatters.py:925, in IPythonDisplayFormatter.__call__(self, obj)
#     923 method = get_real_method(obj, self.print_method)
#     924 if method is not None:
# --> 925     method()
#     926     return True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'alignmentgroup': 'True',
#               'bingroup': 'x',
#               'hovertemplate': 'variable=Close<br>value=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Close',
#               'marker': {'color': 'lightseagreen', 'pattern': {'shape': ''}},
#               'name': 'Close',
#               'offsetgroup': 'Close',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'histogram',
#               'x': array([ 16930.     ,  15851.     ,  16245.     , ..., 124196.     ,
#                           125124.     , 125573.15625]),
#               'xaxis': 'x',
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'height': 400,
#                'legend': {'title': {'text': 'variable'}, 'tracegroupgap': 0},
#                'margin': {'b': 20, 'l': 20, 'r': 20, 't': 20},
#                'paper_bgcolor': '#f7f8fa',
#                'shapes': [{'line': {'color': 'red', 'width': 3},
#                            'type': 'line',
#                            'x0': 58912.29718402027,
#                            'x1': 58912.29718402027,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'line': {'color': 'red', 'dash': 'dash', 'width': 3},
#                            'type': 'line',
#                            'x0': 56097.0,
#                            'x1': 56097.0,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'}],
#                'showlegend': False,
#                'template': '...',
#                'width': 400,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'value'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'count'}}}
# })

# %%
stats.probplot(ibov, dist="norm", plot=pylab)
pylab.show()

# %% [markdown]
# O resultado mostra que estamos muito longe de ter uma distribuição normal.

# %% [markdown]
# Veja a diferença quando modelamos os dados de retornos.

# %%
retornos_ibov = ibov.pct_change()

# %%
retornos_ibov.dropna(inplace=True)

# %%
np.mean(retornos_ibov)
# Out:
# 0.000485240315137433

# %%
fig03 = px.histogram(retornos_ibov, color_discrete_sequence=['lightseagreen'])

fig03.add_vline(x=np.mean(retornos_ibov), line_width=3,  line_color="red")
fig03.add_vline(x=np.median(retornos_ibov), line_width=3, line_dash="dash", line_color="red")

fig03.update_layout(width=400, height=400, template = 'simple_white',
                    paper_bgcolor="#f7f8fa", margin=dict(l=20, r=20, t=20, b=20),
                    showlegend=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\formatters.py:925, in IPythonDisplayFormatter.__call__(self, obj)
#     923 method = get_real_method(obj, self.print_method)
#     924 if method is not None:
# --> 925     method()
#     926     return True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'alignmentgroup': 'True',
#               'bingroup': 'x',
#               'hovertemplate': 'variable=Close<br>value=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Close',
#               'marker': {'color': 'lightseagreen', 'pattern': {'shape': ''}},
#               'name': 'Close',
#               'offsetgroup': 'Close',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'histogram',
#               'x': array([-0.06373302,  0.02485648, -0.00849492, ...,  0.00020134,  0.00747206,
#                            0.00358969]),
#               'xaxis': 'x',
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'height': 400,
#                'legend': {'title': {'text': 'variable'}, 'tracegroupgap': 0},
#                'margin': {'b': 20, 'l': 20, 'r': 20, 't': 20},
#                'paper_bgcolor': '#f7f8fa',
#                'shapes': [{'line': {'color': 'red', 'width': 3},
#                            'type': 'line',
#                            'x0': 0.000485240315137433,
#                            'x1': 0.000485240315137433,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'line': {'color': 'red', 'dash': 'dash', 'width': 3},
#                            'type': 'line',
#                            'x0': 0.0006841338500090943,
#                            'x1': 0.0006841338500090943,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'}],
#                'showlegend': False,
#                'template': '...',
#                'width': 400,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'value'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'count'}}}
# })

# %%
stats.probplot(retornos_ibov, dist="norm", plot=pylab)
pylab.show()

# %% [markdown]
# Assimetria e Curtose

# %%
stats.skew(retornos_ibov)
# Out:
# -0.12096670050787416

# %%
stats.kurtosis(retornos_ibov, fisher=True)
# Out:
# 6.368118631535284

# %% [markdown]
# # Dividendos em PETR4

# %%
dividendos_petr4 = vbt.YFData.download('PETR4.SA').get(['Close', 'Dividends'])

# %%
dividendos_petr4.head()
# Out:
#                               Close  Dividends
# Date
# 2000-01-03 02:00:00+00:00  1.548671        0.0
# 2000-01-04 02:00:00+00:00  1.463000        0.0
# 2000-01-05 02:00:00+00:00  1.448237        0.0
# 2000-01-06 02:00:00+00:00  1.443229        0.0
# 2000-01-07 02:00:00+00:00  1.449819        0.0

# %% [markdown]
# Calculando o Dividend Yield
#
# Se você não sabe o que são Dividendos ou Dividend Yield, não se preocupe! Esse assunto será abordado no detalhe no módulo de análise fundamentalista.
#
# A intenção aqui é utilizar esta métrica apenas para análise estatística, e não entrar no detalhe dos aspectos de mercado financeiro em si.

# %%
dividendos_petr4['soma_dividendos'] = dividendos_petr4.Dividends.rolling('365D').sum()
# Out:
# C:\Users\akira\AppData\Local\Temp\ipykernel_1408\3126120492.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dividendos_petr4.tail()
# Out:
#                                Close  Dividends  soma_dividendos
# Date
# 2024-04-16 03:00:00+00:00  39.490002        0.0         7.328321
# 2024-04-17 03:00:00+00:00  39.779999        0.0         7.328321
# 2024-04-18 03:00:00+00:00  39.849998        0.0         7.328321
# 2024-04-19 03:00:00+00:00  40.529999        0.0         7.328321
# 2024-04-22 03:00:00+00:00  41.500000        0.0         7.328321

# %%
dividendos_petr4.soma_dividendos.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
dividendos_petr4['DY'] = dividendos_petr4['soma_dividendos']/dividendos_petr4.Close * 100

# %% [markdown]
# Para evitar grandes distorções, vamos remover os dias onde não houve pagamento de dividendos

# %%
dy_petr4 = dividendos_petr4[dividendos_petr4['Dividends']!=0]

# %%
dy_petr4.Dividends.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
dy_petr4.DY.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
np.mean(dy_petr4.DY)
# Out:
# 18.562726024360142

# %%
sns.distplot(dy_petr4.DY, hist=True, kde=True)
# Out:
# C:\Users\akira\AppData\Local\Temp\ipykernel_1408\1258609923.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='DY', ylabel='Density'>

# %%
stats.probplot(dy_petr4.DY, dist='norm', plot=pylab)
pylab.show()

# %%
fig04 = px.scatter(x=dy_petr4.Close, y=dy_petr4.DY, width=500)

fig04.update_layout(width=500, height=500, template = 'simple_white', 
                    paper_bgcolor="#f7f8fa", margin=dict(l=20, r=20, t=20, b=20),
                    showlegend=False, xaxis_title='<b>Preço PETR4 (R$)', yaxis_title='<b>DY PETR4 (%)')
                    
fig04.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 7
#       1 fig04 = px.scatter(x=dy_petr4.Close, y=dy_petr4.DY, width=500)
#       3 fig04.update_layout(width=500, height=500, template = 'simple_white',
#       4                     paper_bgcolor="#f7f8fa", margin=dict(l=20, r=20, t=20, b=20),
#       5                     showlegend=False, xaxis_title='<b>Preço PETR4 (R$)', yaxis_title='<b>DY PETR4 (%)')
# ----> 7 fig04.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\plotly\basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
#    3407 """
#    3408 import plotly.io as pio
# -> 3410 return pio.show(self, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %% [markdown]
# # Médias Moveis

# %%
spread

# %% [markdown]
# # **3. Teste de Hipótese, p-valor e magnitude**
# ## *Estatística inferencial*
# A estatística é uma **ciência sobre a incerteza**: probabilidade de um fenômeno ocorrer, desde que satisfeitas um conjunto de condições teóricas

# %% [markdown]
# Fenômeno/observação comumente estão enviesados
#
#
# Baseado no nosso passado e experiências prévias, tendemos a chegar a conclusões distorcidas.

# %% [markdown]
# Na estatística inferencial, fazemos:
#
# * Inferir sobre uma variável da população com base nos dados das amostras (repetições) - é muito difícil estudar a população inteira
#
# * Generalizar uma observação a partir de probabilidades
